# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

ds=sb.load_dataset('titanic')
ds.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sb
sb.displot(x = ds['age'], bins = 10, kde=False )
# Out:
# D:\setups\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.jointplot(x = ds['age'], y = ds['fare'], kind ='scatter')
# For Plot 2
sb.jointplot(x = ds['age'], y = ds['fare'], kind = 'hex')

# %%
sb.rugplot(ds['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
sb.barplot(x='sex', y='age', data=ds)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
import seaborn as sb
sb.barplot(x='sex', y='age', data=ds, estimator=np.std)
# Out:
# D:\setups\anaconda\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.countplot(x='sex', data=ds)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sb.boxplot(x='sex', y='age', data=ds)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.boxplot(x='sex', y='age', data=ds, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.violinplot(x='sex', y='age', data=ds)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.violinplot(x='sex', y='age', data=ds, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.stripplot(x='sex', y='age', data=ds, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.stripplot(x='sex', y='age', data=ds, jitter=True, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.swarmplot(x='sex', y='age', data=ds)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.swarmplot(x='sex', y='age', data=ds, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset = sns.load_dataset('titanic')
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
numeric_dataset = dataset.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
corr = numeric_dataset.corr()

# Plot the heatmap
sb.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
ds=dataset.select_dtypes(include=['float64','int64'])
corr01=ds.corr()
sb.heatmap(corr01)
# Out:
# <Axes: >

# %%
sb.histplot(ds['fare'], kde=False, bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
